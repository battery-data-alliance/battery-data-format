# %% [markdown]
# ## 2. Visualize
#
# Now let's plot the data. If the plot method is provided only a BDF dataframe, then by default it will show Voltage vs. Test Time. Alternatively, we can specify the specific quantities we want to show. A comprehensive overview of visualization features (e.g. unit conversions, exporting, etc.) is included in the visualization notebook.

# %%
bdf.plot(
    df,
    xdata="Test Time / s",
    ydata="Discharging Energy / Wh",
    yydata="Current / A"
)
