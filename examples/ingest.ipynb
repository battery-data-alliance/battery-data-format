# %% [markdown]
# # Ingest raw data into BDF
#
# This notebook demonstrates `bdf.ingest`, which:
#
# - converts raw vendor files into BDF artifacts
# - validates existing BDF files
# - writes outputs to parquet by default (csv optional)

# %%
from pathlib import Path
import bdf

# %% [markdown]
# ## Pick a source directory
#
# By default this uses the local `data/` folder in the repo.

# %%
source_dir = Path("./in/ingest/example_raw_data_collection/g20m7")
source_dir.exists()
# Out:
# True

# %% [markdown]
# ## Run ingest
#
# The ingest function converts all the raw files in a directory and serializes them as .bdf in a subdirectory data/ . It also reads the metadata files to serialize RDF linked data descriptions.

# %%
summary = bdf.ingest(
    source_dir,
    format="parquet",
    recursive=True,
    validate_existing=True,
    validate_converted=True,
    raise_on_error=False,
    layout="nested"
)
summary
# Out:
# {'converted': [],
#  'validated': [],
#  'failed': [],
#  'skipped': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\.bdf.state.json',
#    'reason': 'metadata_file'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\battery.json',
#    'reason': 'metadata_file'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\collection.json',
#    'reason': 'metadata_file'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\metadata.jsonld',
#    'reason': 'metadata_file'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\person.json',
#    'reason': 'metadata_file'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.nda',
#    'reason': 'unchanged'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9\\metadata.jsonld',
#    'reason': 'metadata_file'}],
#  'metadata': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7',
#    'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\metadata.jsonld'},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9',
#    'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9\\metadata.jsonld'}],
#  'metadata_failed': []}

# %% [markdown]
# ## Inspect results

# %%
print("converted:", len(summary.get("converted", [])))
print("validated:", len(summary.get("validated", [])))
print("failed:", len(summary.get("failed", [])))
print("skipped:", len(summary.get("skipped", [])))
# Out:
# converted: 0
# validated: 0
# failed: 0
# skipped: 7

# %%
summary.get("failed", [])[:5]
# Out:
# []

# %% [markdown]
# ## Ingest a repository
#
# Use `bdf.ingest` with `discover_collections=True` to ingest every folder
# that contains `collection.json`.

# %%
repo_root = Path("./in/ingest/example_raw_data_collection")
repo_summary = bdf.ingest(repo_root, layout="nested", format="parquet", discover_collections=True)
repo_summary
# Out:
# {'roots': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7',
#    'summary': {'converted': [],
#     'validated': [],
#     'failed': [],
#     'skipped': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\.bdf.state.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\battery.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\collection.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\person.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.nda',
#       'reason': 'unchanged'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9\\metadata.jsonld',
#       'reason': 'metadata_file'}],
#     'metadata': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\g20m7\\c5hnd9\\metadata.jsonld'}],
#     'metadata_failed': []}},
#   {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10',
#    'summary': {'converted': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\data\\SINTEF__hina-nacr32140mp10-202410-3gvjz6__20250617__2C__25degC.bdf.parquet',
#       'output': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\data\\SINTEF__hina-nacr32140mp10-202410-3gvjz6__20250617__2C__25degC.bdf.parquet',
#       'existing_bdf': True}],
#     'validated': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\data\\SINTEF__hina-nacr32140mp10-202410-3gvjz6__20250617__2C__25degC.bdf.parquet',
#       'ok': True,
#       'report': {'ok': True,
#        'missing': [],
#        'extras': [],
#        'required': ('Test Time / s', 'Voltage / V', 'Current / A'),
#        'optional': ('Unix Time / s',
#         'Cycle Count / 1',
#         'Step Count / 1',
#         'Ambient Temperature / degC',
#         'Step Index / 1',
#         'Charging Capacity / Ah',
#         'Discharging Capacity / Ah',
#         'Step Capacity / Ah',
#         'Net Capacity / Ah',
#         'Cumulative Capacity / Ah',
#         'Charging Energy / Wh',
#         'Discharging Energy / Wh',
#         'Step Energy / Wh',
#         'Net Energy / Wh',
#         'Cumulative Energy / Wh',
#         'Power / W',
#         'Internal Resistance / ohm',
#         'Ambient Pressure / Pa',
#         'Applied Pressure / Pa',
#         'Surface Temperature T1 / degC',
#         'Surface Temperature T2 / degC',
#         'Surface Temperature T3 / degC',
#         'Surface Temperature T4 / degC',
#         'Surface Temperature T5 / degC'),
#        'n_rows': 14243,
#        'n_cols': 14,
#        'time_stats': {'present': True,
#         'monotonic': True,
#         'violations': 0,
#         'min_drop': 0.0,
#         'first_bad_index': None,
#         'epsilon': 0.21850001068069105}}}],
#     'failed': [],
#     'skipped': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\.bdf.state.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\battery.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\collection.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\person.json',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\SINTEF__hina-nacr32140mp10-202410-3gvjz6__20250617__2C__25degC.mpt',
#       'reason': 'unchanged'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\3gvjz6\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\9peqy1\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\e6yezv\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\mhpggp\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\r30yqg\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\v0pygf\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\wv5jgv\\metadata.jsonld',
#       'reason': 'metadata_file'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\z1nxja\\metadata.jsonld',
#       'reason': 'metadata_file'}],
#     'metadata': [{'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\wv5jgv',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\wv5jgv\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\r30yqg',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\r30yqg\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\9peqy1',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\9peqy1\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\e6yezv',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\e6yezv\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\mhpggp',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\mhpggp\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\z1nxja',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\z1nxja\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\3gvjz6',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\3gvjz6\\metadata.jsonld'},
#      {'path': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\v0pygf',
#       'metadata': 'C:\\Users\\simonc\\Documents\\Github-local\\battery_data_alliance\\battery-data-format\\examples\\in\\ingest\\example_raw_data_collection\\nacr32140mp10\\v0pygf\\metadata.jsonld'}],
#     'metadata_failed': []}}],
#  'errors': []}

# %% [markdown]
# ## Notes
#
# - Use `format="csv"` if you need `.bdf.csv` output instead of parquet.
