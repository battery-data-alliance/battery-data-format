# %%
from bdf.metadata import BDFMetadata, Creator, DataDownload

meta = BDFMetadata(
    title="Digatron INR21700 HPPC",
    creators=[Creator(name="Example Creator J", orcid="0000-0002-0000-0010", given_name="Example", family_name="Creator", affiliation="Your Lab")],
    description="HPPC characterization of an INR21700 cell at 25°C on a Digatron cycler.",
    keywords=["li-ion", "inr21700", "hppc"],
    license="CC-BY-4.0",
    url="https://example.org/datasets/digatron-inr21700-hppc",
    version="1.0.0",
    publication_date="2025-06-06",
)

dist = DataDownload(
    url="https://zenodo.org/records/17289383/files/FZJ__INR21700__20250606__HPPC__25degC__Digatron.csv",
    name="Digatron CSV file",
    encoding_format="text/csv",
    description="Primary CSV export from Digatron cycler.",
    csvw_table_schema_url="https://example.org/schemas/bdf-table.schema.json",
)

meta.save_jsonld(
    "dataset.schema.jsonld",
    dataset_uri="https://doi.org/10.5281/zenodo.16994937#digatron-csv-li-ion-hppc",
    identifier="digatron-csv-li-ion-hppc",
    distributions=[dist],
    df=df,  # optional to auto-populate variableMeasured from DataFrame
)

meta.save_rich_results_html(
    "dataset.html",
    title="Digatron INR21700 HPPC",
    graphify=True,
    dataset_uri="https://doi.org/10.5281/zenodo.16994937#digatron-csv-li-ion-hppc",
    identifier="digatron-csv-li-ion-hppc",
    distributions=[dist],
    df=df
)
