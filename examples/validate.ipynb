# %% [markdown]
# ## 2. Validate
#
# We can check to be sure that our dataframe is valid according to the rules of BDF. This can also be used to validated existing files or integrated into your own tools or workflows.

# %%
bdf.validate(df)
