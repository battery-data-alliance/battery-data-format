# %% [markdown]
# # Registry ingest and search
#
# This notebook demonstrates how to ingest metadata sources into the
# BDF registry and query them with `bdf.search()` and `bdf.sparql()`.

# %% [markdown]
# ## Setup
#
# Install BDF first: `pip install bdf`.

# %%
from pathlib import Path
import bdf

# %% [markdown]
# ## Crawl a trusted source
#
# This builds `registry.ttl` and `registry.db` under the default
# registry directory (or `BDF_REGISTRY_DIR` if set).

# %%
source = "https://github.com/DigiBatt/battery-data/tree/main"
registry_dir = Path("out/registry")
summary = bdf.ingest_sources(source, registry_dir=registry_dir, refresh=False)
summary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 source = "https://github.com/DigiBatt/battery-data/tree/main"
#       2 registry_dir = Path("out/registry")
# ----> 3 summary = bdf.ingest_sources(source, registry_dir=registry_dir, refresh=False)
#       4 summary
#
# AttributeError: module 'bdf' has no attribute 'ingest_sources'

# %% [markdown]
# By default, `bdf.search()` and `bdf.sparql()` will query the official BDF registry.
# Until that exists, pass `registry_dir` to query a local registry build.

# %% [markdown]
# ## Fast search
#
# `bdf.search()` queries the local `registry.db` index.

# %%
bdf.search("graphite", registry_dir=registry_dir)[:5]
# Out:
# [{'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C30',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C30.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C30"]',
#   'keywords': '["ici", "hppc", "gitt", "icp6/65/75", "li-ion", "g20m7", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["hppc", "ici", "gitt", "li-ion", "g20m7", "icp6/65/75", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["g20m7", "gitt", "icp6/65/75", "battery", "ici", "hppc", "li-ion"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["gru6mv", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C5',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C5.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C5"]',
#   'keywords': '["battery", "ici", "hppc", "li-ion", "g20m7", "gitt", "icp6/65/75"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["kcsb0s", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - ICI',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: ICI.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["ICI"]',
#   'keywords': '["g20m7", "icp6/65/75", "battery", "ici", "hppc", "gitt", "li-ion"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["kcsb0s", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925}]

# %%
bdf.search("hppc", registry_dir=registry_dir)[:5]
# Out:
# [{'dataset_uri': 'N46e738c9493741e1b6afa7eb595e6594',
#   'dataset_id': 'N46e738c9493741e1b6afa7eb595e6594',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones.',
#   'url': None,
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': None,
#   'keywords': '["g20m7", "icp6/65/75", "battery", "ici", "hppc", "gitt", "li-ion"]',
#   'chemistry': None,
#   'materials': '[]',
#   'pe_materials': '[]',
#   'ne_materials': '[]',
#   'form_factor': None,
#   'manufacturer': None,
#   'model': None,
#   'battery_ids': '[]',
#   'rated_capacity_ah': None,
#   'rated_energy_wh': None,
#   'nominal_voltage_v': None,
#   'mass_g': None,
#   'volume_l': None},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C30',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C30.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C30"]',
#   'keywords': '["ici", "hppc", "gitt", "icp6/65/75", "li-ion", "g20m7", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["hppc", "ici", "gitt", "li-ion", "g20m7", "icp6/65/75", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["g20m7", "gitt", "icp6/65/75", "battery", "ici", "hppc", "li-ion"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["gru6mv", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C5',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C5.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C5"]',
#   'keywords': '["battery", "ici", "hppc", "li-ion", "g20m7", "gitt", "icp6/65/75"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["kcsb0s", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925}]

# %%
bdf.search(">=3 Ah", registry_dir=registry_dir)[:5]
# Out:
# [{'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - ICI',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: ICI.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["ICI"]',
#   'keywords': '["g20m7", "icp6/65/75", "battery", "ici", "hppc", "gitt", "li-ion"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["kcsb0s", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["g20m7", "gitt", "icp6/65/75", "battery", "ici", "hppc", "li-ion"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["gru6mv", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C5',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C5.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C5"]',
#   'keywords': '["battery", "ici", "hppc", "li-ion", "g20m7", "gitt", "icp6/65/75"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["kcsb0s", "ICP6/65/75"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C30',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: C30.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["C30"]',
#   'keywords': '["ici", "hppc", "gitt", "icp6/65/75", "li-ion", "g20m7", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925},
#  {'dataset_uri': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet#dataset',
#   'dataset_id': 'data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'title': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC',
#   'description': 'Performance data for the G20M7 lithium-ion battery used in Google Pixel 10 mobile phones. Measurement technique: HPPC.',
#   'url': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet',
#   'license': 'https://spdx.org/licenses/CC-BY-4.0',
#   'methods': '["HPPC"]',
#   'keywords': '["hppc", "ici", "gitt", "li-ion", "g20m7", "icp6/65/75", "battery"]',
#   'chemistry': 'li-ion',
#   'materials': '["cobalt", "graphite"]',
#   'pe_materials': '["cobalt"]',
#   'ne_materials': '["graphite"]',
#   'form_factor': 'prismatic',
#   'manufacturer': 'Google',
#   'model': 'G20M7',
#   'battery_ids': '["ICP6/65/75", "c5hnd9"]',
#   'rated_capacity_ah': 4.835,
#   'rated_energy_wh': 18.8,
#   'nominal_voltage_v': 3.9,
#   'mass_g': 63.0,
#   'volume_l': 0.02925}]

# %% [markdown]
# ## SPARQL queries
#
# Use `bdf.sparql()` to run linked-data queries against `registry.ttl`.

# %%
query = """
SELECT ?dataset ?name
WHERE {
  # ?dataset a <https://schema.org/Dataset> ;
           <https://schema.org/name> ?name .
}
LIMIT 5
"""
bdf.sparql(query, registry_dir=registry_dir)
# Out:
# [{'dataset': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260109__C30__25degC.bdf.parquet#dataset',
#   'name': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C30'},
#  {'dataset': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-c5hnd9__20260112__HPPC__25degC.bdf.parquet#dataset',
#   'name': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC'},
#  {'dataset': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-gru6mv__20260109__HPPC__25degC.bdf.parquet#dataset',
#   'name': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - HPPC'},
#  {'dataset': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__C5__25degC.bdf.parquet#dataset',
#   'name': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - C5'},
#  {'dataset': 'https://github.com/digibatt/battery-data/google/g20m7/202512/data/SINTEF__google-g20m7-202512-kcsb0s__20260109__ICI__25degC.bdf.parquet#dataset',
#   'name': 'Google Pixel 10 Battery – G20M7 Lithium-Ion Cell Test Data - ICI'}]
